# %% [markdown]
# ## Add site + shcools_if_unit_X

# %%
<Data xmlns="services.schema.networkapi.jmp.juniper.net">
  <CustomAction xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="ServiceCustomActionType">
    <Action>SaveAndValidate</Action>
  </CustomAction>
  <ServiceResource>
    <ServiceOrder>
      <Common>
        <Name>scoileanna.20200917_modify_Sep-24-2020_14-58</Name>
        <Comments/>
        <CreatedBy>super</CreatedBy>
      </Common>
      <EnableMVPN>false</EnableMVPN>
      <ServiceEndPointGroup>
        <DeviceInfo>
          <NA>
            <DeviceName>dist2-testlab</DeviceName>
            <DeviceID>31424514</DeviceID>
          </NA>
        </DeviceInfo>
        <ServiceEndPoint>
          <InterfaceName>ge-0/3/9</InterfaceName>
          <InterfaceStatus>down</InterfaceStatus>
          <ServiceEndpointConfiguration xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="L3VPNFMSTATICEndPointConfigParameterOrderType">
            <UNIDescription>(ZZ) if 114 desc</UNIDescription>
            <EthernetOption>Dot1Q</EthernetOption>
            <AutoPickUnitID>false</AutoPickUnitID>
            <UnitID>114</UnitID>
            <AutoPickVlanID>false</AutoPickVlanID>
            <VlanId>114</VlanId>
            <InterfaceIP AutoPick="false">10.10.14.1</InterfaceIP>
            <IPBlockSize>30</IPBlockSize>
            <MTU>1522</MTU>
            <RouteDistinguisher>1213:4</RouteDistinguisher>
          </ServiceEndpointConfiguration>
          <ServiceTemplates>
            <ServiceTemplate>
              <ID>32768029</ID>
              <Name>schools_if_unitX_v1</Name>
              <ConfigParams>
                <Name>Mtu</Name>
                <Value>1500</Value>
                <Xpath>/configuration/cp1/interfaces/interface[@rowId="1"]/unit[@rowId="1"]/family/inet/mtu</Xpath>
                <ConfigPageName>cp1</ConfigPageName>
              </ConfigParams>
              <ConfigParams>
                <Name>Input</Name>
                <Value>true</Value>
                <Xpath>/configuration/cp1/interfaces/interface[@rowId="1"]/unit[@rowId="1"]/family/inet/sampling/input</Xpath>
                <ConfigPageName>cp1</ConfigPageName>
              </ConfigParams>
              <ConfigParams>
                <Name>Output</Name>
                <Value>true</Value>
                <Xpath>/configuration/cp1/interfaces/interface[@rowId="1"]/unit[@rowId="1"]/family/inet/sampling/output</Xpath>
                <ConfigPageName>cp1</ConfigPageName>
              </ConfigParams>
              <ConfigParams>
                <Name>Name</Name>
                <Value>fd00:10:10:14::1/126</Value>
                <Xpath>/configuration/cp1/interfaces/interface[@rowId="1"]/unit[@rowId="1"]/family/inet6/address[@rowId="1"]/name</Xpath>
                <ConfigPageName>cp1</ConfigPageName>
              </ConfigParams>
              <ConfigParams>
                <Name>Mtu</Name>
                <Value>1500</Value>
                <Xpath>/configuration/cp1/interfaces/interface[@rowId="1"]/unit[@rowId="1"]/family/inet6/mtu</Xpath>
                <ConfigPageName>cp1</ConfigPageName>
              </ConfigParams>
              <ConfigParams>
                <Name>Input</Name>
                <Value>false</Value>
                <Xpath>/configuration/cp1/interfaces/interface[@rowId="1"]/unit[@rowId="1"]/family/inet6/sampling/input</Xpath>
                <ConfigPageName>cp1</ConfigPageName>
              </ConfigParams>
              <ConfigParams>
                <Name>Output</Name>
                <Value>false</Value>
                <Xpath>/configuration/cp1/interfaces/interface[@rowId="1"]/unit[@rowId="1"]/family/inet6/sampling/output</Xpath>
                <ConfigPageName>cp1</ConfigPageName>
              </ConfigParams>
            </ServiceTemplate>
          </ServiceTemplates>
          <OppType>ADD</OppType>
        </ServiceEndPoint>
        <DonotApplyDefaultTemplatesOfSD>true</DonotApplyDefaultTemplatesOfSD>
        <EnableStitchingPoint>false</EnableStitchingPoint>
      </ServiceEndPointGroup>
      <ServiceOrderParameter xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="L3VPNConfigParameterOrderType"/>
      <Reference>
        <Customer key="30900306"/>
        <ServiceDefinition>
          <ServiceDefinitionID key="24215577"/>
        </ServiceDefinition>
        <Service key="32473128"/>
      </Reference>
    </ServiceOrder>
  </ServiceResource>
</Data>

# %% [markdown]
# ## Full mesh, Site add, X interface + rate limiting

# %%
<?xml version="1.0" encoding="UTF-8" standalone="yes"?>
<Data xmlns="services.schema.networkapi.jmp.juniper.net">
  <CustomAction xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="ServiceCustomActionType">
    <Action>SaveAndValidate</Action>
  </CustomAction>
  <ServiceResource>
    <ServiceOrder>
      <Common>
        <Name>scoileanna.20200917_modify_Dec-02-2020_17-43</Name>
        <Comments>service_order_comment</Comments>
        <CreatedBy>dlete-np</CreatedBy>
      </Common>
      <EnableMVPN>false</EnableMVPN>
      <ServiceEndPointGroup>
        <DeviceInfo>
          <NA>
            <DeviceName>dist2-testlab</DeviceName>
            <DeviceID>31424514</DeviceID>
          </NA>
        </DeviceInfo>
        <ServiceEndPoint>
          <InterfaceName>ge-0/3/8</InterfaceName>
          <InterfaceStatus>down</InterfaceStatus>
          <ServiceEndpointConfiguration xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="L3VPNFMSTATICEndPointConfigParameterOrderType">
            <IFDDescription>(ZZ) unit 13, bogus first interface</IFDDescription>
            <EthernetOption>Dot1Q</EthernetOption>
            <AutoPickUnitID>false</AutoPickUnitID>
            <UnitID>13</UnitID>
            <AutoPickVlanID>false</AutoPickVlanID>
            <VlanId>13</VlanId>
            <InterfaceIP AutoPick="false">10.100.38.1</InterfaceIP>
            <IPBlockSize>30</IPBlockSize>
            <MTU>1522</MTU>
            <RouteDistinguisher>1213:4</RouteDistinguisher>
          </ServiceEndpointConfiguration>
          <ServiceTemplates>
            <ServiceTemplate>
              <ID>32768029</ID>
              <Name>schools_if_unitX_v1</Name>
              <ConfigParams>
                <Name>Mtu</Name>
                <Value>1500</Value>
                <Xpath>/configuration/cp1/interfaces/interface[@rowId="1"]/unit[@rowId="1"]/family/inet/mtu</Xpath>
                <ConfigPageName>cp1</ConfigPageName>
              </ConfigParams>
              <ConfigParams>
                <Name>Input</Name>
                <Value>true</Value>
                <Xpath>/configuration/cp1/interfaces/interface[@rowId="1"]/unit[@rowId="1"]/family/inet/sampling/input</Xpath>
                <ConfigPageName>cp1</ConfigPageName>
              </ConfigParams>
              <ConfigParams>
                <Name>Output</Name>
                <Value>true</Value>
                <Xpath>/configuration/cp1/interfaces/interface[@rowId="1"]/unit[@rowId="1"]/family/inet/sampling/output</Xpath>
                <ConfigPageName>cp1</ConfigPageName>
              </ConfigParams>
              <ConfigParams>
                <Name>Name</Name>
                <Value>fd00:10:100:38::1/126</Value>
                <Xpath>/configuration/cp1/interfaces/interface[@rowId="1"]/unit[@rowId="1"]/family/inet6/address[@rowId="1"]/name</Xpath>
                <ConfigPageName>cp1</ConfigPageName>
              </ConfigParams>
              <ConfigParams>
                <Name>Mtu</Name>
                <Value>1500</Value>
                <Xpath>/configuration/cp1/interfaces/interface[@rowId="1"]/unit[@rowId="1"]/family/inet6/mtu</Xpath>
                <ConfigPageName>cp1</ConfigPageName>
              </ConfigParams>
              <ConfigParams>
                <Name>Input</Name>
                <Value>false</Value>
                <Xpath>/configuration/cp1/interfaces/interface[@rowId="1"]/unit[@rowId="1"]/family/inet6/sampling/input</Xpath>
                <ConfigPageName>cp1</ConfigPageName>
              </ConfigParams>
              <ConfigParams>
                <Name>Output</Name>
                <Value>false</Value>
                <Xpath>/configuration/cp1/interfaces/interface[@rowId="1"]/unit[@rowId="1"]/family/inet6/sampling/output</Xpath>
                <ConfigPageName>cp1</ConfigPageName>
              </ConfigParams>
            </ServiceTemplate>
            <ServiceTemplate>
              <ID>32768000</ID>
              <Name>if_v1</Name>
              <ConfigParams>
                <Name>Description</Name>
                <Value>[ZZ] [INTERCONNECT] BOGUS OPEN EIR ID 8888</Value>
                <Xpath>/configuration/cp1/interfaces/interface[@rowId="1"]/description</Xpath>
                <ConfigPageName>cp1</ConfigPageName>
              </ConfigParams>
              <ConfigParams>
                <Name>Mtu</Name>
                <Value>1522</Value>
                <Xpath>/configuration/cp1/interfaces/interface[@rowId="1"]/mtu</Xpath>
                <ConfigPageName>cp1</ConfigPageName>
              </ConfigParams>
            </ServiceTemplate>
            <ServiceTemplate>
              <ID>32768025</ID>
              <Name>if_unit_inet_policer_out_v1</Name>
              <ConfigParams>
                <Name>Output</Name>
                <Value>test_schools_policer_open_eir</Value>
                <Xpath>/configuration/cp1/interfaces/interface[@rowId="1"]/unit[@rowId="1"]/family/inet/policer/output</Xpath>
                <ConfigPageName>cp1</ConfigPageName>
              </ConfigParams>
            </ServiceTemplate>
            <ServiceTemplate>
              <ID>32768024</ID>
              <Name>cos_if_unit_rewrite_802.1_v1</Name>
              <ConfigParams>
                <Name>Rewrite-rule-name</Name>
                <Value>test_schools_rewrite-rule_open_eir</Value>
                <Xpath>/configuration/cp1/class-of-service/interfaces/interface[@rowId="1"]/unit[@rowId="1"]/rewrite-rules/ieee-802.1/rewrite-rule-name</Xpath>
                <ConfigPageName>cp1</ConfigPageName>
              </ConfigParams>
            </ServiceTemplate>
          </ServiceTemplates>
          <OppType>ADD</OppType>
        </ServiceEndPoint>
        <DonotApplyDefaultTemplatesOfSD>true</DonotApplyDefaultTemplatesOfSD>
        <EnableStitchingPoint>false</EnableStitchingPoint>
      </ServiceEndPointGroup>
      <ServiceOrderParameter xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="L3VPNConfigParameterOrderType"/>
      <Reference>
        <Customer key="30900306"/>
        <ServiceDefinition>
          <ServiceDefinitionID key="24215577"/>
        </ServiceDefinition>
        <Service key="32473128"/>
      </Reference>
    </ServiceOrder>
  </ServiceResource>
</Data>

# %% [markdown]
# ## Get an IP service by service id

# %%
{
    "Data": {
        "ServiceResource": {
            "Service": {
                "@key": "32473128",
                "@uri": "/api/space/nsas/l3vpn/service-management/services/32473128",
                "@href": "/api/space/nsas/l3vpn/service-management/services/32473128",
                "Common": {
                    "Name": "scoileanna.20200917",
                    "Identity": 32473128,
                    "State": "Deployed",
                    "CreatedDate": "2020-09-17T15:26:37.000Z",
                    "LastUpdatedDate": "2020-09-17T15:30:41.000Z",
                    "InstanceType": "vrf"
                },
                "ServiceType": "L3VPN",
                "EnableMVPN": false,
                "AuditFlag": {
                    "FunctionalAudit": "Pending",
                    "ConfigurationAudit": "Pending",
                    "FaultStatus": "None",
                    "SLAStatus": "None",
                    "OverallStatus": "N/A"
                },
                "endpointcount": 0,
                "ServiceEndPointGroup": {
                    "DeviceInfo": {
                        "NA": {
                            "@key": "31424514",
                            "@uri": "/api/space/nsas/device-roles/pe-devices/31424514",
                            "@href": "/api/space/nsas/device-roles/pe-devices/31424514",
                            "DeviceName": "dist2-testlab",
                            "DeviceID": 31424514
                        }
                    },
                    "ServiceEndPoint": {
                        "InterfaceName": "ge-0/3/9",
                        "InterfaceId": 31522869,
                        "InterfaceStatus": "down",
                        "ServiceEndpointConfiguration": {
                            "@xsi.type": "L3VPNFMSTATICEndPointConfigParameterOrderType",
                            "UNIDescription": "(UN) 12345A - ACME AM91919",
                            "IFDDescription": "ACME SHS",
                            "RoutingProtocol": "Static",
                            "EthernetOption": "Dot1Q",
                            "AutoPickUnitID": false,
                            "UnitID": 13,
                            "VlanId": 13,
                            "InterfaceIP": "10.10.13.2/31",
                            "MTU": 1522,
                            "RouteDistinguisher": "1213:4"
                        },
                        "ServiceTemplates": {
                            "ServiceTemplate": [
                                {
                                    "@href": "/api/space/nsas/l3vpn/service-management/service-templates/32768000",
                                    "@uri": "/api/space/nsas/l3vpn/service-management/service-templates/32768000",
                                    "@key": "32768000",
                                    "ID": 32768000,
                                    "Name": "if_v1",
                                    "ConfigParams": [
                                        {
                                            "Name": "Description",
                                            "DataType": "String",
                                            "Description": "Text description of interface",
                                            "OperatorVisibility": "Editable",
                                            "Value": "[UN] [INTERCONNECT] ACME SHS",
                                            "SetofValues": "",
                                            "Xpath": "/configuration/cp1/interfaces/interface[@rowId=\"1\"]/description",
                                            "Decommission": false,
                                            "SvcSpecificValue": false,
                                            "ConfigPageName": "cp1",
                                            "Validation": ""
                                        },
                                        {
                                            "Name": "Mtu",
                                            "DataType": "Number",
                                            "Description": "Maximum transmit packet size",
                                            "OperatorVisibility": "Editable",
                                            "Value": 1522,
                                            "SetofValues": "",
                                            "Xpath": "/configuration/cp1/interfaces/interface[@rowId=\"1\"]/mtu",
                                            "Decommission": false,
                                            "SvcSpecificValue": false,
                                            "ConfigPageName": "cp1",
                                            "Validation": {
                                                "MaxLengthStr": 9216,
                                                "MinLengthStr": 256
                                            }
                                        }
                                    ]
                                },
                                {
                                    "@href": "/api/space/nsas/l3vpn/service-management/service-templates/32768029",
                                    "@uri": "/api/space/nsas/l3vpn/service-management/service-templates/32768029",
                                    "@key": "32768029",
                                    "ID": 32768029,
                                    "Name": "schools_if_unitX_v1",
                                    "ConfigParams": [
                                        {
                                            "Name": "Mtu",
                                            "DataType": "Number",
                                            "Description": "Protocol family maximum transmission unit",
                                            "OperatorVisibility": "Editable",
                                            "Value": 1500,
                                            "SetofValues": "",
                                            "Xpath": "/configuration/cp1/interfaces/interface[@rowId=\"1\"]/unit[@rowId=\"1\"]/family/inet/mtu",
                                            "Decommission": false,
                                            "SvcSpecificValue": false,
                                            "ConfigPageName": "cp1",
                                            "Validation": {
                                                "MaxLengthStr": 4294967295,
                                                "MinLengthStr": 0
                                            }
                                        },
                                        {
                                            "Name": "Input",
                                            "DataType": "Boolean",
                                            "Description": "Sample all packets input on this interface",
                                            "OperatorVisibility": "Editable",
                                            "Value": true,
                                            "SetofValues": "",
                                            "Xpath": "/configuration/cp1/interfaces/interface[@rowId=\"1\"]/unit[@rowId=\"1\"]/family/inet/sampling/input",
                                            "Decommission": false,
                                            "SvcSpecificValue": false,
                                            "ConfigPageName": "cp1",
                                            "Validation": ""
                                        },
                                        {
                                            "Name": "Output",
                                            "DataType": "Boolean",
                                            "Description": "Sample all packets output on this interface",
                                            "OperatorVisibility": "Editable",
                                            "Value": true,
                                            "SetofValues": "",
                                            "Xpath": "/configuration/cp1/interfaces/interface[@rowId=\"1\"]/unit[@rowId=\"1\"]/family/inet/sampling/output",
                                            "Decommission": false,
                                            "SvcSpecificValue": false,
                                            "ConfigPageName": "cp1",
                                            "Validation": ""
                                        },
                                        {
                                            "Name": "Name",
                                            "DataType": "String",
                                            "Description": "Interface address or destination prefix",
                                            "OperatorVisibility": "Editable",
                                            "Value": "fd00:10:10:13::1/126",
                                            "SetofValues": "",
                                            "Xpath": "/configuration/cp1/interfaces/interface[@rowId=\"1\"]/unit[@rowId=\"1\"]/family/inet6/address[@rowId=\"1\"]/name",
                                            "Decommission": false,
                                            "SvcSpecificValue": false,
                                            "ConfigPageName": "cp1",
                                            "Validation": ""
                                        },
                                        {
                                            "Name": "Mtu",
                                            "DataType": "Number",
                                            "Description": "Protocol family maximum transmission unit",
                                            "OperatorVisibility": "Editable",
                                            "Value": 1500,
                                            "SetofValues": "",
                                            "Xpath": "/configuration/cp1/interfaces/interface[@rowId=\"1\"]/unit[@rowId=\"1\"]/family/inet6/mtu",
                                            "Decommission": false,
                                            "SvcSpecificValue": false,
                                            "ConfigPageName": "cp1",
                                            "Validation": {
                                                "MaxLengthStr": 4294967295,
                                                "MinLengthStr": 0
                                            }
                                        },
                                        {
                                            "Name": "Input",
                                            "DataType": "Boolean",
                                            "Description": "Sample all packets input on this interface",
                                            "OperatorVisibility": "Editable",
                                            "Value": false,
                                            "SetofValues": "",
                                            "Xpath": "/configuration/cp1/interfaces/interface[@rowId=\"1\"]/unit[@rowId=\"1\"]/family/inet6/sampling/input",
                                            "Decommission": false,
                                            "SvcSpecificValue": false,
                                            "ConfigPageName": "cp1",
                                            "Validation": ""
                                        },
                                        {
                                            "Name": "Output",
                                            "DataType": "Boolean",
                                            "Description": "Sample all packets output on this interface",
                                            "OperatorVisibility": "Editable",
                                            "Value": false,
                                            "SetofValues": "",
                                            "Xpath": "/configuration/cp1/interfaces/interface[@rowId=\"1\"]/unit[@rowId=\"1\"]/family/inet6/sampling/output",
                                            "Decommission": false,
                                            "SvcSpecificValue": false,
                                            "ConfigPageName": "cp1",
                                            "Validation": ""
                                        }
                                    ]
                                },
                                {
                                    "@href": "/api/space/nsas/l3vpn/service-management/service-templates/32768032",
                                    "@uri": "/api/space/nsas/l3vpn/service-management/service-templates/32768032",
                                    "@key": "32768032",
                                    "ID": 32768032,
                                    "Name": "schools_ri_bgp_inet_v2",
                                    "ConfigParams": [
                                        {
                                            "Name": "Allow[@rowId=\"1\"]",
                                            "DataType": "String",
                                            "Description": "Configure peer connections for specific networks",
                                            "OperatorVisibility": "Editable",
                                            "Value": "87.32.36.0/22",
                                            "SetofValues": "",
                                            "Xpath": "/configuration/cp1/routing-instances/instance[@rowId=\"1\"]/protocols/bgp/group[@rowId=\"1\"]/allow[@rowId=\"1\"]",
                                            "Decommission": false,
                                            "SvcSpecificValue": false,
                                            "ConfigPageName": "cp1",
                                            "Validation": ""
                                        },
                                        {
                                            "Name": "Allow[@rowId=\"2\"]",
                                            "DataType": "String",
                                            "Description": "Configure peer connections for specific networks",
                                            "OperatorVisibility": "Editable",
                                            "Value": "87.32.36.0/22",
                                            "SetofValues": "",
                                            "Xpath": "/configuration/cp1/routing-instances/instance[@rowId=\"1\"]/protocols/bgp/group[@rowId=\"1\"]/allow[@rowId=\"2\"]",
                                            "Decommission": false,
                                            "SvcSpecificValue": false,
                                            "ConfigPageName": "cp1",
                                            "Validation": ""
                                        },
                                        {
                                            "Name": "Allow[@rowId=\"3\"]",
                                            "DataType": "String",
                                            "Description": "Configure peer connections for specific networks",
                                            "OperatorVisibility": "Editable",
                                            "Value": "87.32.36.0/22",
                                            "SetofValues": "",
                                            "Xpath": "/configuration/cp1/routing-instances/instance[@rowId=\"1\"]/protocols/bgp/group[@rowId=\"1\"]/allow[@rowId=\"3\"]",
                                            "Decommission": false,
                                            "SvcSpecificValue": false,
                                            "ConfigPageName": "cp1",
                                            "Validation": ""
                                        },
                                        {
                                            "Name": "Allow[@rowId=\"4\"]",
                                            "DataType": "String",
                                            "Description": "Configure peer connections for specific networks",
                                            "OperatorVisibility": "Editable",
                                            "Value": "87.32.36.0/22",
                                            "SetofValues": "",
                                            "Xpath": "/configuration/cp1/routing-instances/instance[@rowId=\"1\"]/protocols/bgp/group[@rowId=\"1\"]/allow[@rowId=\"4\"]",
                                            "Decommission": false,
                                            "SvcSpecificValue": false,
                                            "ConfigPageName": "cp1",
                                            "Validation": ""
                                        },
                                        {
                                            "Name": "Allow[@rowId=\"5\"]",
                                            "DataType": "String",
                                            "Description": "Configure peer connections for specific networks",
                                            "OperatorVisibility": "Editable",
                                            "Value": "87.32.60.0/22",
                                            "SetofValues": "",
                                            "Xpath": "/configuration/cp1/routing-instances/instance[@rowId=\"1\"]/protocols/bgp/group[@rowId=\"1\"]/allow[@rowId=\"5\"]",
                                            "Decommission": false,
                                            "SvcSpecificValue": false,
                                            "ConfigPageName": "cp1",
                                            "Validation": ""
                                        },
                                        {
                                            "Name": "Export[@rowId=\"1\"]",
                                            "DataType": "String",
                                            "Description": "Export policy",
                                            "OperatorVisibility": "Editable",
                                            "Value": "deny-all",
                                            "SetofValues": "",
                                            "Xpath": "/configuration/cp1/routing-instances/instance[@rowId=\"1\"]/protocols/bgp/group[@rowId=\"1\"]/export[@rowId=\"1\"]",
                                            "Decommission": false,
                                            "SvcSpecificValue": false,
                                            "ConfigPageName": "cp1",
                                            "Validation": ""
                                        },
                                        {
                                            "Name": "Import[@rowId=\"1\"]",
                                            "DataType": "String",
                                            "Description": "Import policy",
                                            "OperatorVisibility": "Editable",
                                            "Value": "deny-all",
                                            "SetofValues": "",
                                            "Xpath": "/configuration/cp1/routing-instances/instance[@rowId=\"1\"]/protocols/bgp/group[@rowId=\"1\"]/import[@rowId=\"1\"]",
                                            "Decommission": false,
                                            "SvcSpecificValue": false,
                                            "ConfigPageName": "cp1",
                                            "Validation": ""
                                        },
                                        {
                                            "Name": "Maximum",
                                            "DataType": "Number",
                                            "Description": "Maximum number of prefixes from a peer",
                                            "OperatorVisibility": "Editable",
                                            "Value": 10,
                                            "SetofValues": "",
                                            "Xpath": "/configuration/cp1/routing-instances/instance[@rowId=\"1\"]/protocols/bgp/group[@rowId=\"1\"]/inet/prefix-limit/maximum",
                                            "Decommission": false,
                                            "SvcSpecificValue": false,
                                            "ConfigPageName": "cp1",
                                            "Validation": {
                                                "MaxLengthStr": 4294967295,
                                                "MinLengthStr": 1
                                            }
                                        },
                                        {
                                            "Name": "Name",
                                            "DataType": "String",
                                            "Description": "Group name",
                                            "OperatorVisibility": "Editable",
                                            "Value": "SCHOOLS-V4",
                                            "SetofValues": "",
                                            "Xpath": "/configuration/cp1/routing-instances/instance[@rowId=\"1\"]/protocols/bgp/group[@rowId=\"1\"]/name",
                                            "Decommission": false,
                                            "SvcSpecificValue": false,
                                            "ConfigPageName": "cp1",
                                            "Validation": ""
                                        },
                                        {
                                            "Name": "Peer-as",
                                            "DataType": "String",
                                            "Description": "Autonomous system number in plain number or 'higher 16bits'.'Lower 16 bits' (asdot notation) format",
                                            "OperatorVisibility": "Editable",
                                            "Value": 65013,
                                            "SetofValues": "",
                                            "Xpath": "/configuration/cp1/routing-instances/instance[@rowId=\"1\"]/protocols/bgp/group[@rowId=\"1\"]/peer-as",
                                            "Decommission": false,
                                            "SvcSpecificValue": false,
                                            "ConfigPageName": "cp1",
                                            "Validation": ""
                                        },
                                        {
                                            "DataType": "Enumeration",
                                            "Description": "Type of peer group",
                                            "OperatorVisibility": "Readonly",
                                            "Value": "external",
                                            "SetofValues": {
                                                "Value": [
                                                    "internal",
                                                    "external"
                                                ]
                                            },
                                            "Xpath": "/configuration/cp1/routing-instances/instance[@rowId=\"1\"]/protocols/bgp/group[@rowId=\"1\"]/type",
                                            "Decommission": false,
                                            "SvcSpecificValue": false,
                                            "DynamicAttribute": true,
                                            "ConfigPageName": "cp1",
                                            "Validation": ""
                                        },
                                        {
                                            "DataType": "Enumeration",
                                            "Description": "Type of peer group",
                                            "OperatorVisibility": "Readonly",
                                            "Value": "external",
                                            "SetofValues": {
                                                "Value": [
                                                    "internal",
                                                    "external"
                                                ]
                                            },
                                            "Xpath": "/configuration/cp1/routing-instances/instance[@rowId=\"1\"]/protocols/bgp/group[@rowId=\"1\"]/type",
                                            "Decommission": false,
                                            "SvcSpecificValue": false,
                                            "DynamicAttribute": true,
                                            "ConfigPageName": "cp1",
                                            "Validation": ""
                                        }
                                    ]
                                },
                                {
                                    "@href": "/api/space/nsas/l3vpn/service-management/service-templates/32768033",
                                    "@uri": "/api/space/nsas/l3vpn/service-management/service-templates/32768033",
                                    "@key": "32768033",
                                    "ID": 32768033,
                                    "Name": "schools_ri_bgp_inet6_v2",
                                    "ConfigParams": [
                                        {
                                            "Name": "Allow[@rowId=\"1\"]",
                                            "DataType": "String",
                                            "Description": "Configure peer connections for specific networks",
                                            "OperatorVisibility": "Editable",
                                            "Value": "2001:770:e008:5::/64",
                                            "SetofValues": "",
                                            "Xpath": "/configuration/cp1/routing-instances/instance[@rowId=\"1\"]/protocols/bgp/group[@rowId=\"1\"]/allow[@rowId=\"1\"]",
                                            "Decommission": false,
                                            "SvcSpecificValue": false,
                                            "ConfigPageName": "cp1",
                                            "Validation": ""
                                        },
                                        {
                                            "Name": "Allow[@rowId=\"2\"]",
                                            "DataType": "String",
                                            "Description": "Configure peer connections for specific networks",
                                            "OperatorVisibility": "Editable",
                                            "Value": "2001:770:e008:5::/64",
                                            "SetofValues": "",
                                            "Xpath": "/configuration/cp1/routing-instances/instance[@rowId=\"1\"]/protocols/bgp/group[@rowId=\"1\"]/allow[@rowId=\"2\"]",
                                            "Decommission": false,
                                            "SvcSpecificValue": false,
                                            "ConfigPageName": "cp1",
                                            "Validation": ""
                                        },
                                        {
                                            "Name": "Allow[@rowId=\"3\"]",
                                            "DataType": "String",
                                            "Description": "Configure peer connections for specific networks",
                                            "OperatorVisibility": "Editable",
                                            "Value": "2001:770:e008:5::/64",
                                            "SetofValues": "",
                                            "Xpath": "/configuration/cp1/routing-instances/instance[@rowId=\"1\"]/protocols/bgp/group[@rowId=\"1\"]/allow[@rowId=\"3\"]",
                                            "Decommission": false,
                                            "SvcSpecificValue": false,
                                            "ConfigPageName": "cp1",
                                            "Validation": ""
                                        },
                                        {
                                            "Name": "Allow[@rowId=\"4\"]",
                                            "DataType": "String",
                                            "Description": "Configure peer connections for specific networks",
                                            "OperatorVisibility": "Editable",
                                            "Value": "2001:770:e008:5::/64",
                                            "SetofValues": "",
                                            "Xpath": "/configuration/cp1/routing-instances/instance[@rowId=\"1\"]/protocols/bgp/group[@rowId=\"1\"]/allow[@rowId=\"4\"]",
                                            "Decommission": false,
                                            "SvcSpecificValue": false,
                                            "ConfigPageName": "cp1",
                                            "Validation": ""
                                        },
                                        {
                                            "Name": "Allow[@rowId=\"5\"]",
                                            "DataType": "String",
                                            "Description": "Configure peer connections for specific networks",
                                            "OperatorVisibility": "Editable",
                                            "Value": "2001:770:e008:5::/64",
                                            "SetofValues": "",
                                            "Xpath": "/configuration/cp1/routing-instances/instance[@rowId=\"1\"]/protocols/bgp/group[@rowId=\"1\"]/allow[@rowId=\"5\"]",
                                            "Decommission": false,
                                            "SvcSpecificValue": false,
                                            "ConfigPageName": "cp1",
                                            "Validation": ""
                                        },
                                        {
                                            "Name": "Export[@rowId=\"1\"]",
                                            "DataType": "String",
                                            "Description": "Export policy",
                                            "OperatorVisibility": "Editable",
                                            "Value": "deny-all",
                                            "SetofValues": "",
                                            "Xpath": "/configuration/cp1/routing-instances/instance[@rowId=\"1\"]/protocols/bgp/group[@rowId=\"1\"]/export[@rowId=\"1\"]",
                                            "Decommission": false,
                                            "SvcSpecificValue": false,
                                            "ConfigPageName": "cp1",
                                            "Validation": ""
                                        },
                                        {
                                            "Name": "Maximum",
                                            "DataType": "Number",
                                            "Description": "Maximum number of prefixes from a peer",
                                            "OperatorVisibility": "Editable",
                                            "Value": 10,
                                            "SetofValues": "",
                                            "Xpath": "/configuration/cp1/routing-instances/instance[@rowId=\"1\"]/protocols/bgp/group[@rowId=\"1\"]/family/inet6/prefix-limit/maximum",
                                            "Decommission": false,
                                            "SvcSpecificValue": false,
                                            "ConfigPageName": "cp1",
                                            "Validation": {
                                                "MaxLengthStr": 4294967295,
                                                "MinLengthStr": 1
                                            }
                                        },
                                        {
                                            "Name": "Import[@rowId=\"1\"]",
                                            "DataType": "String",
                                            "Description": "Import policy",
                                            "OperatorVisibility": "Editable",
                                            "Value": "deny-all",
                                            "SetofValues": "",
                                            "Xpath": "/configuration/cp1/routing-instances/instance[@rowId=\"1\"]/protocols/bgp/group[@rowId=\"1\"]/import[@rowId=\"1\"]",
                                            "Decommission": false,
                                            "SvcSpecificValue": false,
                                            "ConfigPageName": "cp1",
                                            "Validation": ""
                                        },
                                        {
                                            "Name": "Name",
                                            "DataType": "String",
                                            "Description": "Group name",
                                            "OperatorVisibility": "Editable",
                                            "Value": "SCHOOLS-V6",
                                            "SetofValues": "",
                                            "Xpath": "/configuration/cp1/routing-instances/instance[@rowId=\"1\"]/protocols/bgp/group[@rowId=\"1\"]/name",
                                            "Decommission": false,
                                            "SvcSpecificValue": false,
                                            "ConfigPageName": "cp1",
                                            "Validation": ""
                                        },
                                        {
                                            "Name": "Peer-as",
                                            "DataType": "String",
                                            "Description": "Autonomous system number in plain number or 'higher 16bits'.'Lower 16 bits' (asdot notation) format",
                                            "OperatorVisibility": "Editable",
                                            "Value": 65103,
                                            "SetofValues": "",
                                            "Xpath": "/configuration/cp1/routing-instances/instance[@rowId=\"1\"]/protocols/bgp/group[@rowId=\"1\"]/peer-as",
                                            "Decommission": false,
                                            "SvcSpecificValue": false,
                                            "ConfigPageName": "cp1",
                                            "Validation": ""
                                        },
                                        {
                                            "DataType": "Enumeration",
                                            "Description": "Type of peer group",
                                            "OperatorVisibility": "Readonly",
                                            "Value": "external",
                                            "SetofValues": {
                                                "Value": [
                                                    "internal",
                                                    "external"
                                                ]
                                            },
                                            "Xpath": "/configuration/cp1/routing-instances/instance[@rowId=\"1\"]/protocols/bgp/group[@rowId=\"1\"]/type",
                                            "Decommission": false,
                                            "SvcSpecificValue": false,
                                            "DynamicAttribute": true,
                                            "ConfigPageName": "cp1",
                                            "Validation": ""
                                        },
                                        {
                                            "DataType": "Enumeration",
                                            "Description": "Type of peer group",
                                            "OperatorVisibility": "Readonly",
                                            "Value": "external",
                                            "SetofValues": {
                                                "Value": [
                                                    "internal",
                                                    "external"
                                                ]
                                            },
                                            "Xpath": "/configuration/cp1/routing-instances/instance[@rowId=\"1\"]/protocols/bgp/group[@rowId=\"1\"]/type",
                                            "Decommission": false,
                                            "SvcSpecificValue": false,
                                            "DynamicAttribute": true,
                                            "ConfigPageName": "cp1",
                                            "Validation": ""
                                        }
                                    ]
                                }
                            ]
                        },
                        "ServiceEndpointID": 32702725
                    },
                    "EnableLoopback": false,
                    "EnableStitchingPoint": false
                },
                "ServiceParameters": {
                    "@xsi.type": "L3VPNConfigParameterServiceType",
                    "RouteTarget": "1213:10",
                    "VRFTabelLabel": "Enabled",
                    "ASOverride": false,
                    "IsBGPEpPresent": false,
                    "MaximumPrefixes": 0,
                    "ExportDirectRoutes": true,
                    "PolicyBasedRT": true
                },
                "Reference": {
                    "ServiceOrder": {
                        "@uri": "/api/space/nsas/l3vpn/service-management/service-orders/32604288",
                        "@href": "/api/space/nsas/l3vpn/service-management/service-orders/32604288",
                        "@key": "32604288"
                    },
                    "ServiceDefinition": {
                        "ServiceDefinitionID": {
                            "@uri": "/api/space/nsas/l3vpn/service-management/service-definitions/24215577",
                            "@href": "/api/space/nsas/l3vpn/service-management/service-definitions/24215577",
                            "@key": "24215577",
                            "ServiceDefinitionName": "l3vpn_schools_full_mesh_policy_v1"
                        }
                    },
                    "Customer": {
                        "@uri": "/api/space/nsas/customer-management/customers/30900306",
                        "@href": "/api/space/nsas/customer-management/customers/30900306",
                        "@key": "30900306",
                        "CustomerName": "SCHOOLS"
                    }
                }
            }
        }
    }
}

# %% [markdown]
# # Add site, L3VPN, hub and spoke, Schools with x interface

# %%
<Data xmlns="services.schema.networkapi.jmp.juniper.net">
  <CustomAction xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="ServiceCustomActionType">
    <Action>SaveAndValidate</Action>
  </CustomAction>
  <ServiceResource>
    <ServiceOrder>
      <Common>
        <Name>test.sh_api.site_add_2020-03=09_iiI</Name>
        <Comments>no comment</Comments>
        <CreatedBy>dlete-np</CreatedBy>
      </Common>
      <EnableMVPN>false</EnableMVPN>
      <ServiceEndPointGroup>
        <DeviceInfo>
          <NA>
            <DeviceName>dist2-testlab</DeviceName>
            <DeviceID>21561660</DeviceID>
          </NA>
        </DeviceInfo>
        <ServiceEndPoint>
          <InterfaceName>ge-0/2/2</InterfaceName>
          <InterfaceStatus>down</InterfaceStatus>
          <ServiceEndpointConfiguration xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="L3VPNHSSTATICEndPointConfigParameterOrderType">
            <UNIDescription>if 113 desc</UNIDescription>
            <EthernetOption>Dot1Q</EthernetOption>
            <AutoPickUnitID>false</AutoPickUnitID>
            <UnitID>113</UnitID>
            <AutoPickVlanID>false</AutoPickVlanID>
            <VlanId>113</VlanId>
            <InterfaceIP AutoPick="false">10.10.13.1</InterfaceIP>
            <IPBlockSize>30</IPBlockSize>
            <MTU>1522</MTU>
            <Hub>false</Hub>
            <SpokeRouteDistinguisher AutoPick="false">1213:23</SpokeRouteDistinguisher>
          </ServiceEndpointConfiguration>
          <ServiceTemplates>
            <ServiceTemplate>
              <ID>32768006</ID>
              <Name>schools_if_unitX_v1</Name>
              <ConfigParams>
                <Name>Mtu</Name>
                <Value>1500</Value>
                <Xpath>/configuration/cp1/interfaces/interface[@rowId="1"]/unit[@rowId="1"]/family/inet/mtu</Xpath>
                <ConfigPageName>cp1</ConfigPageName>
              </ConfigParams>
              <ConfigParams>
                <Name>Input</Name>
                <Value>true</Value>
                <Xpath>/configuration/cp1/interfaces/interface[@rowId="1"]/unit[@rowId="1"]/family/inet/sampling/input</Xpath>
                <ConfigPageName>cp1</ConfigPageName>
              </ConfigParams>
              <ConfigParams>
                <Name>Output</Name>
                <Value>true</Value>
                <Xpath>/configuration/cp1/interfaces/interface[@rowId="1"]/unit[@rowId="1"]/family/inet/sampling/output</Xpath>
                <ConfigPageName>cp1</ConfigPageName>
              </ConfigParams>
              <ConfigParams>
                <Name>Name</Name>
                <Value>fd00:10:10:13::1/126</Value>
                <Xpath>/configuration/cp1/interfaces/interface[@rowId="1"]/unit[@rowId="1"]/family/inet6/address[@rowId="1"]/name</Xpath>
                <ConfigPageName>cp1</ConfigPageName>
              </ConfigParams>
              <ConfigParams>
                <Name>Mtu</Name>
                <Value>1500</Value>
                <Xpath>/configuration/cp1/interfaces/interface[@rowId="1"]/unit[@rowId="1"]/family/inet6/mtu</Xpath>
                <ConfigPageName>cp1</ConfigPageName>
              </ConfigParams>
              <ConfigParams>
                <Name>Input</Name>
                <Value>false</Value>
                <Xpath>/configuration/cp1/interfaces/interface[@rowId="1"]/unit[@rowId="1"]/family/inet6/sampling/input</Xpath>
                <ConfigPageName>cp1</ConfigPageName>
              </ConfigParams>
              <ConfigParams>
                <Name>Output</Name>
                <Value>false</Value>
                <Xpath>/configuration/cp1/interfaces/interface[@rowId="1"]/unit[@rowId="1"]/family/inet6/sampling/output</Xpath>
                <ConfigPageName>cp1</ConfigPageName>
              </ConfigParams>
            </ServiceTemplate>
          </ServiceTemplates>
          <OppType>ADD</OppType>
        </ServiceEndPoint>
        <DonotApplyDefaultTemplatesOfSD>true</DonotApplyDefaultTemplatesOfSD>
        <EnableStitchingPoint>false</EnableStitchingPoint>
      </ServiceEndPointGroup>
      <ServiceOrderParameter xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="L3VPNConfigParameterOrderType"/>
      <Reference>
        <Customer key="950272"/>
        <ServiceDefinition>
          <ServiceDefinitionID key="24281137"/>
        </ServiceDefinition>
        <Service key="32276486"/>
      </Reference>
    </ServiceOrder>
  </ServiceResource>
</Data>

# %% [markdown]
# # Delete site, l3vpn, Schools, hub & spoke

# %%
<Data
	xmlns="services.schema.networkapi.jmp.juniper.net">
	<ServiceResource>
		<ServiceOrder>
			<Common>
				<Name>test.sh_api.site_del_2020-03-09_iii</Name>
				<Comments>no comment</Comments>
				<CreatedBy>dlete-np</CreatedBy>
			</Common>
			<Reference>
				<Customer key="950272"/>
				<ServiceDefinition>
					<ServiceDefinitionID key="24281137"/>
				</ServiceDefinition>
				<Service key="32276486"/>
			</Reference>
			<EnableMVPN>false</EnableMVPN>
			<ServiceOrderParameter
				xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="L3VPNConfigParameterOrderType">
				<ASOverride>false</ASOverride>
			</ServiceOrderParameter>
			<ServiceEndPointGroup>
            <DonotApplyDefaultTemplatesOfSD>true</DonotApplyDefaultTemplatesOfSD>
            <DeviceInfo>
            <NA>
            <DeviceName>dist2-testlab</DeviceName>
            <DeviceID>21561660</DeviceID>
            </NA>
            </DeviceInfo>
            <ServiceEndPoint>
            <InterfaceName>ge-0/2/2</InterfaceName>
            <ServiceEndpointID>32374854</ServiceEndpointID>
            <ServiceEndpointConfiguration 
                xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" 
                xsi:type="VPLSBGPEndPointConfigParameterOrderType">
            <Hub>false</Hub>
            <UnitId>113</UnitId>
            <VlanId>113</VlanId>
            </ServiceEndpointConfiguration>
            <OppType>DELETE</OppType>
            </ServiceEndPoint>
            </ServiceEndPointGroup>
		</ServiceOrder>
	</ServiceResource>
	<CustomAction
		xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="ServiceCustomActionType">
		<Action>SaveAndValidate</Action>
	</CustomAction>
</Data>
